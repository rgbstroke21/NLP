# %% [markdown]
# ## Auto Generate Abstract or Summary
# ---
# #### Workflow
# 1. Identify the most importance words.
# 2. Compute significance score of sentences based on words they contain
# 3. Pick the sentences with top score for summary
# ---
# In this example, we consider the following points
# 1. <b>Word Importance = Word Frequency</b>
# 2. <b>Sentence Score = sum(Word Importances)</b>

# %% [markdown]
# 1. Download and parse Text
#     * Use BeautifulSoup to parse text
# 2. Tokenization and Stop Word Removal
# 3. Extract Sentences
#     * Compute freq of words
#     * Calculate significance score of sentences
#     * Sort sentences by their significance score
#     * Get top N sentences

# %%
import requests
from bs4 import BeautifulSoup

# %%
docurl = 'https://www.bbc.com/news/world-asia-india-60431187'

# %%
def getTextFromUrl(url):
    page = requests.get(url)
    htmlContent = page.content
    soup = BeautifulSoup( htmlContent , 'html.parser')
    text = ' '.join( map( lambda x : x.text , soup.find_all('article') ) )
    return text.replace('\'','')

# %%
text = getTextFromUrl(docurl)
text = text.replace('Image source, Getty ImagesImage caption', ' ')
text = text.replace('By Atul Sangar Editor, BBC News PunjabiPublished18 hours agoSharecloseShare pageCopy linkAbout sharing' , ' ')
# text.replace('.','\t.\t')

# %% [markdown]
# Now we have the text with us. We clean the text for puntuations and extract sentences from it.

# %%
from nltk import sent_tokenize , word_tokenize
from nltk.corpus import stopwords
from string import punctuation

# %%
# sentences = sent_tokenize(text)
sentences = text.split('.')
new_text = '.  '.join(sentences)
new_text
sentences = new_text.split('?')
new_text = '?  '.join(sentences)

# %%
sentences = sent_tokenize( new_text )
sentences
# Out:
# ['Punjab voting: Can AAP triumph over BJP, Congress to win elections?',
#  ', The Aam Aadmi Party is giving a tough fight to the CongressAs the northern Indian state of Punjab votes to choose its next government, theres one buzzword in the air: change.',
#  'Everyone is promising it.',
#  'The Aam Aadmi Party (AAP), which impressively became the main opposition party in its debut in the state in 2017, is counting on its assurance of changing the plight of Punjabs voters to help it win.',
#  'Both the regional Shiromani Akali Dal (SAD) - which had to do massive damage control after initially speaking in favour of the controversial farm laws - and opposition Bharatiya Janata Party (BJP) hope voters discontent with the ruling Congress party will see them through.',
#  'Even the Congress says if given another chance, they will change - by moving away from top-down decisions and keep the common citizen front and centre.',
#  'The India election that will test Modis popularityWhy PM Modi rolled back Indias vexed farm lawsVoters are also clear they want accountability from their representatives, and are unlikely to be swayed by the number of freebies being announced by every political party.',
#  '"Political parties havent solved any of our problems," says Bhano, a Dalit (formerly untouchable) daily-wage labourer who says she hasnt got government assistance despite crushing poverty.',
#  'She echoes the sentiments of millions of ordinary Punjabis who are struggling to find jobs, access public education and health and make a living from agriculture.',
#  '"The awareness that common people need to assert themselves and raise their voices for their rights gained ground during the farmers protests.',
#  'People have now started demanding accountability from their representatives for the promises made to them.',
#  'This will play a role in the voters decision," says Jagtar Singh, a writer and senior journalist.',
#  ', Political parties are offering a slew of freebies to votersThats why the AAP - which has never been in power in Punjab and is showcasing its governance record in national capital Delhi - is giving a tough fight to the Congress, which had won 77 out of 117 assembly seats in the last assembly election.',
#  'Arvind Kejriwal, AAP chief and Delhi chief minister, alleges that both the Congress party and the SAD have failed to keep their promises to people despite being in power for decades since the state was formed in the 1960s.',
#  '"In Delhi, we have provided free medical facilities, improved education in government schools and provided 24-hour electricity supply.',
#  'We will do the same in Punjab if you give us a chance," he says.',
#  'The AAP was the first to announce a chief ministerial candidate - two-time lawmaker Bhagwant Mann, who drew huge crowds throughout the campaign - while other parties were still putting their houses in order.',
#  'The party and Mr Mann have also been targeted by their rivals, establishing them as a major contender for power even in a multi-cornered contest.',
#  'While the AAPs freshness may give it an edge, it wont be a cakewalk.',
#  'Charanjit Singh Channi, current chief minister and the Congresss biggest hope, is from the Dalit community, which forms 32% of Punjabs population.',
#  'In his four months at the helm - after Amarinder Singh left the Congress after a bitter break-up - Mr Channi has projected himself as a common man whose heart beats for the ordinary Punjabi.',
#  ', Chief minister Charanjit Singh Channi (left) is the Congresss big hopeHis appointment in September was seen as a politically astute call by the Congress - it led to fracturing of the power held by the Jat Sikh community and also appealed to Dalits.',
#  'But the Dalit vote is not a monolith so its hard to predict if it will consolidate behind Mr Channi, the states first Dalit chief minister.',
#  'He faces other challenges - the Congress is trying hard to shake off allegations of ineffective governance.',
#  'It was also distracted in recent months by infighting and trying to pacify the bruised egos of top leaders such as Sunil Jakhar and Navjot Singh Sidhu, who hoped Mr Singhs departure would ease their way to the top.',
#  'Mr Channis image was also dented by a raid by the Enforcement Directorate, a federal agency that fights financial crime, on his nephew over allegations corruption in sand mining contracts - Mr Channi has said these were politically motivated.',
#  'He also sparked a controversy by asking voters not to give chances to "outsiders" from Uttar Pradesh and Bihar - in an apparent attack on Mr Kejriwal and Mr Modi who are not from Punjab.',
#  'He was forced to clarify later that he didnt mean any disrespect to people of Uttar Pradesh and Bihar.',
#  'Prime Minister Narendra Modi from the BJP had pounced on it, accusing Mr Channi of insulting the states icons.',
#  '"Who is the chief minister insulting?',
#  'Sant Ravi Dass (a Dalit icon) was born in Benaras (in Uttar Pradesh state).',
#  'Where was Guru Gobind Singh (the last of the 10 Sikh gurus) born (Patna in Bihar)?  "',
#  'he asked at a recent rally.',
#  'Mr Modis BJP is in an alliance with two regional parties, including the one formed by Mr Singh, the former Congress chief minister.',
#  ', PM Modis (right) BJP is in alliance with former chief minister Amarinder Singh (left)The prime minister has also attacked Mr Kejriwal based on an unverified allegation made by one of the AAP leaders former colleagues, who has accused him of supporting Sikh separatists.',
#  'Mr Kejriwal has dismissed the allegation, saying he must be "the worlds sweetest terrorist who builds hospitals".',
#  'The BJP is also battling farmer anger over the three controversial laws that were repealed after a year of protests.',
#  'But its alliance may get a push from the Hindu minority community in the state, which has usually sided with the party in power at the centre.',
#  'The SAD, which walked out of its alliance with the BJP over the farm laws, is trying hard to regain lost ground.',
#  'It was expected to see a revival after the Congress couldnt prove the allegations - which propelled it to power in 2017 - that senior SAD leaders had colluded with people responsible for incidents of sacrilege between 2014 and 2015.',
#  'But that hope was dashed when it took too long to announce a strong stand against the farm laws.',
#  'While it later supported the farmers protests, resigned from Mr Modis cabinet and cut ties with the BJP, the issue still rankles in the minds of many voters.',
#  'The party, like its rivals, has announced a slew of freebies, including interest-free education loans for students to go abroad - which counts on the aspirations among young people to migrate to other countries due to lack of jobs in Punjab.',
#  'Though the farmers protest was a big election issue, candidates backed by the Sanyukt Samaj Morcha, an alliance of 22 farmer unions, which took shape after the agitation, are unlikely to win, observers say.',
#  'Read our coverage of elections in India:The India election that will test Modis popularityWhy west Uttar Pradesh could hurt BJP’s poll dreamsAre women thriving in India state as PM Modi claims?',
#  'Is the Congress party feud in Punjab really over?',
#  'More on this storyIs the Congress party feud in Punjab really over?',
#  '7 FebruaryWhy PM Modi rolled back Indias vexed farm laws19 November 2021Related TopicsAsiaIndia']

# %%
words = word_tokenize(text.lower())
words
# Out:
# ['punjab',
#  'voting',
#  ':',
#  'can',
#  'aap',
#  'triumph',
#  'over',
#  'bjp',
#  ',',
#  'congress',
#  'to',
#  'win',
#  'elections',
#  '?',
#  ',',
#  'the',
#  'aam',
#  'aadmi',
#  'party',
#  'is',
#  'giving',
#  'a',
#  'tough',
#  'fight',
#  'to',
#  'the',
#  'congressas',
#  'the',
#  'northern',
#  'indian',
#  'state',
#  'of',
#  'punjab',
#  'votes',
#  'to',
#  'choose',
#  'its',
#  'next',
#  'government',
#  ',',
#  'theres',
#  'one',
#  'buzzword',
#  'in',
#  'the',
#  'air',
#  ':',
#  'change.everyone',
#  'is',
#  'promising',
#  'it',
#  '.',
#  'the',
#  'aam',
#  'aadmi',
#  'party',
#  '(',
#  'aap',
#  ')',
#  ',',
#  'which',
#  'impressively',
#  'became',
#  'the',
#  'main',
#  'opposition',
#  'party',
#  'in',
#  'its',
#  'debut',
#  'in',
#  'the',
#  'state',
#  'in',
#  '2017',
#  ',',
#  'is',
#  'counting',
#  'on',
#  'its',
#  'assurance',
#  'of',
#  'changing',
#  'the',
#  'plight',
#  'of',
#  'punjabs',
#  'voters',
#  'to',
#  'help',
#  'it',
#  'win.both',
#  'the',
#  'regional',
#  'shiromani',
#  'akali',
#  'dal',
#  '(',
#  'sad',
#  ')',
#  '-',
#  'which',
#  'had',
#  'to',
#  'do',
#  'massive',
#  'damage',
#  'control',
#  'after',
#  'initially',
#  'speaking',
#  'in',
#  'favour',
#  'of',
#  'the',
#  'controversial',
#  'farm',
#  'laws',
#  '-',
#  'and',
#  'opposition',
#  'bharatiya',
#  'janata',
#  'party',
#  '(',
#  'bjp',
#  ')',
#  'hope',
#  'voters',
#  'discontent',
#  'with',
#  'the',
#  'ruling',
#  'congress',
#  'party',
#  'will',
#  'see',
#  'them',
#  'through.even',
#  'the',
#  'congress',
#  'says',
#  'if',
#  'given',
#  'another',
#  'chance',
#  ',',
#  'they',
#  'will',
#  'change',
#  '-',
#  'by',
#  'moving',
#  'away',
#  'from',
#  'top-down',
#  'decisions',
#  'and',
#  'keep',
#  'the',
#  'common',
#  'citizen',
#  'front',
#  'and',
#  'centre.the',
#  'india',
#  'election',
#  'that',
#  'will',
#  'test',
#  'modis',
#  'popularitywhy',
#  'pm',
#  'modi',
#  'rolled',
#  'back',
#  'indias',
#  'vexed',
#  'farm',
#  'lawsvoters',
#  'are',
#  'also',
#  'clear',
#  'they',
#  'want',
#  'accountability',
#  'from',
#  'their',
#  'representatives',
#  ',',
#  'and',
#  'are',
#  'unlikely',
#  'to',
#  'be',
#  'swayed',
#  'by',
#  'the',
#  'number',
#  'of',
#  'freebies',
#  'being',
#  'announced',
#  'by',
#  'every',
#  'political',
#  'party',
#  '.',
#  '``',
#  'political',
#  'parties',
#  'havent',
#  'solved',
#  'any',
#  'of',
#  'our',
#  'problems',
#  ',',
#  "''",
#  'says',
#  'bhano',
#  ',',
#  'a',
#  'dalit',
#  '(',
#  'formerly',
#  'untouchable',
#  ')',
#  'daily-wage',
#  'labourer',
#  'who',
#  'says',
#  'she',
#  'hasnt',
#  'got',
#  'government',
#  'assistance',
#  'despite',
#  'crushing',
#  'poverty.she',
#  'echoes',
#  'the',
#  'sentiments',
#  'of',
#  'millions',
#  'of',
#  'ordinary',
#  'punjabis',
#  'who',
#  'are',
#  'struggling',
#  'to',
#  'find',
#  'jobs',
#  ',',
#  'access',
#  'public',
#  'education',
#  'and',
#  'health',
#  'and',
#  'make',
#  'a',
#  'living',
#  'from',
#  'agriculture',
#  '.',
#  '``',
#  'the',
#  'awareness',
#  'that',
#  'common',
#  'people',
#  'need',
#  'to',
#  'assert',
#  'themselves',
#  'and',
#  'raise',
#  'their',
#  'voices',
#  'for',
#  'their',
#  'rights',
#  'gained',
#  'ground',
#  'during',
#  'the',
#  'farmers',
#  'protests',
#  '.',
#  'people',
#  'have',
#  'now',
#  'started',
#  'demanding',
#  'accountability',
#  'from',
#  'their',
#  'representatives',
#  'for',
#  'the',
#  'promises',
#  'made',
#  'to',
#  'them',
#  '.',
#  'this',
#  'will',
#  'play',
#  'a',
#  'role',
#  'in',
#  'the',
#  'voters',
#  'decision',
#  ',',
#  "''",
#  'says',
#  'jagtar',
#  'singh',
#  ',',
#  'a',
#  'writer',
#  'and',
#  'senior',
#  'journalist',
#  '.',
#  ',',
#  'political',
#  'parties',
#  'are',
#  'offering',
#  'a',
#  'slew',
#  'of',
#  'freebies',
#  'to',
#  'votersthats',
#  'why',
#  'the',
#  'aap',
#  '-',
#  'which',
#  'has',
#  'never',
#  'been',
#  'in',
#  'power',
#  'in',
#  'punjab',
#  'and',
#  'is',
#  'showcasing',
#  'its',
#  'governance',
#  'record',
#  'in',
#  'national',
#  'capital',
#  'delhi',
#  '-',
#  'is',
#  'giving',
#  'a',
#  'tough',
#  'fight',
#  'to',
#  'the',
#  'congress',
#  ',',
#  'which',
#  'had',
#  'won',
#  '77',
#  'out',
#  'of',
#  '117',
#  'assembly',
#  'seats',
#  'in',
#  'the',
#  'last',
#  'assembly',
#  'election.arvind',
#  'kejriwal',
#  ',',
#  'aap',
#  'chief',
#  'and',
#  'delhi',
#  'chief',
#  'minister',
#  ',',
#  'alleges',
#  'that',
#  'both',
#  'the',
#  'congress',
#  'party',
#  'and',
#  'the',
#  'sad',
#  'have',
#  'failed',
#  'to',
#  'keep',
#  'their',
#  'promises',
#  'to',
#  'people',
#  'despite',
#  'being',
#  'in',
#  'power',
#  'for',
#  'decades',
#  'since',
#  'the',
#  'state',
#  'was',
#  'formed',
#  'in',
#  'the',
#  '1960s',
#  '.',
#  '``',
#  'in',
#  'delhi',
#  ',',
#  'we',
#  'have',
#  'provided',
#  'free',
#  'medical',
#  'facilities',
#  ',',
#  'improved',
#  'education',
#  'in',
#  'government',
#  'schools',
#  'and',
#  'provided',
#  '24-hour',
#  'electricity',
#  'supply',
#  '.',
#  'we',
#  'will',
#  'do',
#  'the',
#  'same',
#  'in',
#  'punjab',
#  'if',
#  'you',
#  'give',
#  'us',
#  'a',
#  'chance',
#  ',',
#  "''",
#  'he',
#  'says.the',
#  'aap',
#  'was',
#  'the',
#  'first',
#  'to',
#  'announce',
#  'a',
#  'chief',
#  'ministerial',
#  'candidate',
#  '-',
#  'two-time',
#  'lawmaker',
#  'bhagwant',
#  'mann',
#  ',',
#  'who',
#  'drew',
#  'huge',
#  'crowds',
#  'throughout',
#  'the',
#  'campaign',
#  '-',
#  'while',
#  'other',
#  'parties',
#  'were',
#  'still',
#  'putting',
#  'their',
#  'houses',
#  'in',
#  'order',
#  '.',
#  'the',
#  'party',
#  'and',
#  'mr',
#  'mann',
#  'have',
#  'also',
#  'been',
#  'targeted',
#  'by',
#  'their',
#  'rivals',
#  ',',
#  'establishing',
#  'them',
#  'as',
#  'a',
#  'major',
#  'contender',
#  'for',
#  'power',
#  'even',
#  'in',
#  'a',
#  'multi-cornered',
#  'contest.while',
#  'the',
#  'aaps',
#  'freshness',
#  'may',
#  'give',
#  'it',
#  'an',
#  'edge',
#  ',',
#  'it',
#  'wont',
#  'be',
#  'a',
#  'cakewalk.charanjit',
#  'singh',
#  'channi',
#  ',',
#  'current',
#  'chief',
#  'minister',
#  'and',
#  'the',
#  'congresss',
#  'biggest',
#  'hope',
#  ',',
#  'is',
#  'from',
#  'the',
#  'dalit',
#  'community',
#  ',',
#  'which',
#  'forms',
#  '32',
#  '%',
#  'of',
#  'punjabs',
#  'population',
#  '.',
#  'in',
#  'his',
#  'four',
#  'months',
#  'at',
#  'the',
#  'helm',
#  '-',
#  'after',
#  'amarinder',
#  'singh',
#  'left',
#  'the',
#  'congress',
#  'after',
#  'a',
#  'bitter',
#  'break-up',
#  '-',
#  'mr',
#  'channi',
#  'has',
#  'projected',
#  'himself',
#  'as',
#  'a',
#  'common',
#  'man',
#  'whose',
#  'heart',
#  'beats',
#  'for',
#  'the',
#  'ordinary',
#  'punjabi',
#  '.',
#  ',',
#  'chief',
#  'minister',
#  'charanjit',
#  'singh',
#  'channi',
#  '(',
#  'left',
#  ')',
#  'is',
#  'the',
#  'congresss',
#  'big',
#  'hopehis',
#  'appointment',
#  'in',
#  'september',
#  'was',
#  'seen',
#  'as',
#  'a',
#  'politically',
#  'astute',
#  'call',
#  'by',
#  'the',
#  'congress',
#  '-',
#  'it',
#  'led',
#  'to',
#  'fracturing',
#  'of',
#  'the',
#  'power',
#  'held',
#  'by',
#  'the',
#  'jat',
#  'sikh',
#  'community',
#  'and',
#  'also',
#  'appealed',
#  'to',
#  'dalits.but',
#  'the',
#  'dalit',
#  'vote',
#  'is',
#  'not',
#  'a',
#  'monolith',
#  'so',
#  'its',
#  'hard',
#  'to',
#  'predict',
#  'if',
#  'it',
#  'will',
#  'consolidate',
#  'behind',
#  'mr',
#  'channi',
#  ',',
#  'the',
#  'states',
#  'first',
#  'dalit',
#  'chief',
#  'minister.he',
#  'faces',
#  'other',
#  'challenges',
#  '-',
#  'the',
#  'congress',
#  'is',
#  'trying',
#  'hard',
#  'to',
#  'shake',
#  'off',
#  'allegations',
#  'of',
#  'ineffective',
#  'governance',
#  '.',
#  'it',
#  'was',
#  'also',
#  'distracted',
#  'in',
#  'recent',
#  'months',
#  'by',
#  'infighting',
#  'and',
#  'trying',
#  'to',
#  'pacify',
#  'the',
#  'bruised',
#  'egos',
#  'of',
#  'top',
#  'leaders',
#  'such',
#  'as',
#  'sunil',
#  'jakhar',
#  'and',
#  'navjot',
#  'singh',
#  'sidhu',
#  ',',
#  'who',
#  'hoped',
#  'mr',
#  'singhs',
#  'departure',
#  'would',
#  'ease',
#  'their',
#  'way',
#  'to',
#  'the',
#  'top',
#  '.',
#  'mr',
#  'channis',
#  'image',
#  'was',
#  'also',
#  'dented',
#  'by',
#  'a',
#  'raid',
#  'by',
#  'the',
#  'enforcement',
#  'directorate',
#  ',',
#  'a',
#  'federal',
#  'agency',
#  'that',
#  'fights',
#  'financial',
#  'crime',
#  ',',
#  'on',
#  'his',
#  'nephew',
#  'over',
#  'allegations',
#  'corruption',
#  'in',
#  'sand',
#  'mining',
#  'contracts',
#  '-',
#  'mr',
#  'channi',
#  'has',
#  'said',
#  'these',
#  'were',
#  'politically',
#  'motivated.he',
#  'also',
#  'sparked',
#  'a',
#  'controversy',
#  'by',
#  'asking',
#  'voters',
#  'not',
#  'to',
#  'give',
#  'chances',
#  'to',
#  '``',
#  'outsiders',
#  "''",
#  'from',
#  'uttar',
#  'pradesh',
#  'and',
#  'bihar',
#  '-',
#  'in',
#  'an',
#  'apparent',
#  'attack',
#  'on',
#  'mr',
#  'kejriwal',
#  'and',
#  'mr',
#  'modi',
#  'who',
#  'are',
#  'not',
#  'from',
#  'punjab',
#  '.',
#  'he',
#  'was',
#  'forced',
#  'to',
#  'clarify',
#  'later',
#  'that',
#  'he',
#  'didnt',
#  'mean',
#  'any',
#  'disrespect',
#  'to',
#  'people',
#  'of',
#  'uttar',
#  'pradesh',
#  'and',
#  'bihar.prime',
#  'minister',
#  'narendra',
#  'modi',
#  'from',
#  'the',
#  'bjp',
#  'had',
#  'pounced',
#  'on',
#  'it',
#  ',',
#  'accusing',
#  'mr',
#  'channi',
#  'of',
#  'insulting',
#  'the',
#  'states',
#  'icons',
#  '.',
#  '``',
#  'who',
#  'is',
#  'the',
#  'chief',
#  'minister',
#  'insulting',
#  '?',
#  'sant',
#  'ravi',
#  'dass',
#  '(',
#  'a',
#  'dalit',
#  'icon',
#  ')',
#  'was',
#  'born',
#  'in',
#  'benaras',
#  '(',
#  'in',
#  'uttar',
#  'pradesh',
#  'state',
#  ')',
#  '.',
#  'where',
#  'was',
#  'guru',
#  'gobind',
#  'singh',
#  '(',
#  'the',
#  'last',
#  'of',
#  'the',
#  '10',
#  'sikh',
#  'gurus',
#  ')',
#  'born',
#  '(',
#  'patna',
#  'in',
#  'bihar',
#  ')',
#  '?',
#  "''",
#  'he',
#  'asked',
#  'at',
#  'a',
#  'recent',
#  'rally.mr',
#  'modis',
#  'bjp',
#  'is',
#  'in',
#  'an',
#  'alliance',
#  'with',
#  'two',
#  'regional',
#  'parties',
#  ',',
#  'including',
#  'the',
#  'one',
#  'formed',
#  'by',
#  'mr',
#  'singh',
#  ',',
#  'the',
#  'former',
#  'congress',
#  'chief',
#  'minister',
#  '.',
#  ',',
#  'pm',
#  'modis',
#  '(',
#  'right',
#  ')',
#  'bjp',
#  'is',
#  'in',
#  'alliance',
#  'with',
#  'former',
#  'chief',
#  'minister',
#  'amarinder',
#  'singh',
#  '(',
#  'left',
#  ')',
#  'the',
#  'prime',
#  'minister',
#  'has',
#  'also',
#  'attacked',
#  'mr',
#  'kejriwal',
#  'based',
#  'on',
#  'an',
#  'unverified',
#  'allegation',
#  'made',
#  'by',
#  'one',
#  'of',
#  'the',
#  'aap',
#  'leaders',
#  'former',
#  'colleagues',
#  ',',
#  'who',
#  'has',
#  'accused',
#  'him',
#  'of',
#  'supporting',
#  'sikh',
#  'separatists.mr',
#  'kejriwal',
#  'has',
#  'dismissed',
#  'the',
#  'allegation',
#  ',',
#  'saying',
#  'he',
#  'must',
#  'be',
#  '``',
#  'the',
#  'worlds',
#  'sweetest',
#  'terrorist',
#  'who',
#  'builds',
#  'hospitals',
#  "''",
#  '.the',
#  'bjp',
#  ...]

# %% [markdown]
# We first need to remove stopwords and punctuations

# %%
newStopWords = set( stopwords.words('english') + list(punctuation) )

# %%
words = [ word for word in words if word not in newStopWords]

# %%
words
# Out:
# ['punjab',
#  'voting',
#  'aap',
#  'triumph',
#  'bjp',
#  'congress',
#  'win',
#  'elections',
#  'aam',
#  'aadmi',
#  'party',
#  'giving',
#  'tough',
#  'fight',
#  'congressas',
#  'northern',
#  'indian',
#  'state',
#  'punjab',
#  'votes',
#  'choose',
#  'next',
#  'government',
#  'theres',
#  'one',
#  'buzzword',
#  'air',
#  'change.everyone',
#  'promising',
#  'aam',
#  'aadmi',
#  'party',
#  'aap',
#  'impressively',
#  'became',
#  'main',
#  'opposition',
#  'party',
#  'debut',
#  'state',
#  '2017',
#  'counting',
#  'assurance',
#  'changing',
#  'plight',
#  'punjabs',
#  'voters',
#  'help',
#  'win.both',
#  'regional',
#  'shiromani',
#  'akali',
#  'dal',
#  'sad',
#  'massive',
#  'damage',
#  'control',
#  'initially',
#  'speaking',
#  'favour',
#  'controversial',
#  'farm',
#  'laws',
#  'opposition',
#  'bharatiya',
#  'janata',
#  'party',
#  'bjp',
#  'hope',
#  'voters',
#  'discontent',
#  'ruling',
#  'congress',
#  'party',
#  'see',
#  'through.even',
#  'congress',
#  'says',
#  'given',
#  'another',
#  'chance',
#  'change',
#  'moving',
#  'away',
#  'top-down',
#  'decisions',
#  'keep',
#  'common',
#  'citizen',
#  'front',
#  'centre.the',
#  'india',
#  'election',
#  'test',
#  'modis',
#  'popularitywhy',
#  'pm',
#  'modi',
#  'rolled',
#  'back',
#  'indias',
#  'vexed',
#  'farm',
#  'lawsvoters',
#  'also',
#  'clear',
#  'want',
#  'accountability',
#  'representatives',
#  'unlikely',
#  'swayed',
#  'number',
#  'freebies',
#  'announced',
#  'every',
#  'political',
#  'party',
#  '``',
#  'political',
#  'parties',
#  'havent',
#  'solved',
#  'problems',
#  "''",
#  'says',
#  'bhano',
#  'dalit',
#  'formerly',
#  'untouchable',
#  'daily-wage',
#  'labourer',
#  'says',
#  'hasnt',
#  'got',
#  'government',
#  'assistance',
#  'despite',
#  'crushing',
#  'poverty.she',
#  'echoes',
#  'sentiments',
#  'millions',
#  'ordinary',
#  'punjabis',
#  'struggling',
#  'find',
#  'jobs',
#  'access',
#  'public',
#  'education',
#  'health',
#  'make',
#  'living',
#  'agriculture',
#  '``',
#  'awareness',
#  'common',
#  'people',
#  'need',
#  'assert',
#  'raise',
#  'voices',
#  'rights',
#  'gained',
#  'ground',
#  'farmers',
#  'protests',
#  'people',
#  'started',
#  'demanding',
#  'accountability',
#  'representatives',
#  'promises',
#  'made',
#  'play',
#  'role',
#  'voters',
#  'decision',
#  "''",
#  'says',
#  'jagtar',
#  'singh',
#  'writer',
#  'senior',
#  'journalist',
#  'political',
#  'parties',
#  'offering',
#  'slew',
#  'freebies',
#  'votersthats',
#  'aap',
#  'never',
#  'power',
#  'punjab',
#  'showcasing',
#  'governance',
#  'record',
#  'national',
#  'capital',
#  'delhi',
#  'giving',
#  'tough',
#  'fight',
#  'congress',
#  '77',
#  '117',
#  'assembly',
#  'seats',
#  'last',
#  'assembly',
#  'election.arvind',
#  'kejriwal',
#  'aap',
#  'chief',
#  'delhi',
#  'chief',
#  'minister',
#  'alleges',
#  'congress',
#  'party',
#  'sad',
#  'failed',
#  'keep',
#  'promises',
#  'people',
#  'despite',
#  'power',
#  'decades',
#  'since',
#  'state',
#  'formed',
#  '1960s',
#  '``',
#  'delhi',
#  'provided',
#  'free',
#  'medical',
#  'facilities',
#  'improved',
#  'education',
#  'government',
#  'schools',
#  'provided',
#  '24-hour',
#  'electricity',
#  'supply',
#  'punjab',
#  'give',
#  'us',
#  'chance',
#  "''",
#  'says.the',
#  'aap',
#  'first',
#  'announce',
#  'chief',
#  'ministerial',
#  'candidate',
#  'two-time',
#  'lawmaker',
#  'bhagwant',
#  'mann',
#  'drew',
#  'huge',
#  'crowds',
#  'throughout',
#  'campaign',
#  'parties',
#  'still',
#  'putting',
#  'houses',
#  'order',
#  'party',
#  'mr',
#  'mann',
#  'also',
#  'targeted',
#  'rivals',
#  'establishing',
#  'major',
#  'contender',
#  'power',
#  'even',
#  'multi-cornered',
#  'contest.while',
#  'aaps',
#  'freshness',
#  'may',
#  'give',
#  'edge',
#  'wont',
#  'cakewalk.charanjit',
#  'singh',
#  'channi',
#  'current',
#  'chief',
#  'minister',
#  'congresss',
#  'biggest',
#  'hope',
#  'dalit',
#  'community',
#  'forms',
#  '32',
#  'punjabs',
#  'population',
#  'four',
#  'months',
#  'helm',
#  'amarinder',
#  'singh',
#  'left',
#  'congress',
#  'bitter',
#  'break-up',
#  'mr',
#  'channi',
#  'projected',
#  'common',
#  'man',
#  'whose',
#  'heart',
#  'beats',
#  'ordinary',
#  'punjabi',
#  'chief',
#  'minister',
#  'charanjit',
#  'singh',
#  'channi',
#  'left',
#  'congresss',
#  'big',
#  'hopehis',
#  'appointment',
#  'september',
#  'seen',
#  'politically',
#  'astute',
#  'call',
#  'congress',
#  'led',
#  'fracturing',
#  'power',
#  'held',
#  'jat',
#  'sikh',
#  'community',
#  'also',
#  'appealed',
#  'dalits.but',
#  'dalit',
#  'vote',
#  'monolith',
#  'hard',
#  'predict',
#  'consolidate',
#  'behind',
#  'mr',
#  'channi',
#  'states',
#  'first',
#  'dalit',
#  'chief',
#  'minister.he',
#  'faces',
#  'challenges',
#  'congress',
#  'trying',
#  'hard',
#  'shake',
#  'allegations',
#  'ineffective',
#  'governance',
#  'also',
#  'distracted',
#  'recent',
#  'months',
#  'infighting',
#  'trying',
#  'pacify',
#  'bruised',
#  'egos',
#  'top',
#  'leaders',
#  'sunil',
#  'jakhar',
#  'navjot',
#  'singh',
#  'sidhu',
#  'hoped',
#  'mr',
#  'singhs',
#  'departure',
#  'would',
#  'ease',
#  'way',
#  'top',
#  'mr',
#  'channis',
#  'image',
#  'also',
#  'dented',
#  'raid',
#  'enforcement',
#  'directorate',
#  'federal',
#  'agency',
#  'fights',
#  'financial',
#  'crime',
#  'nephew',
#  'allegations',
#  'corruption',
#  'sand',
#  'mining',
#  'contracts',
#  'mr',
#  'channi',
#  'said',
#  'politically',
#  'motivated.he',
#  'also',
#  'sparked',
#  'controversy',
#  'asking',
#  'voters',
#  'give',
#  'chances',
#  '``',
#  'outsiders',
#  "''",
#  'uttar',
#  'pradesh',
#  'bihar',
#  'apparent',
#  'attack',
#  'mr',
#  'kejriwal',
#  'mr',
#  'modi',
#  'punjab',
#  'forced',
#  'clarify',
#  'later',
#  'didnt',
#  'mean',
#  'disrespect',
#  'people',
#  'uttar',
#  'pradesh',
#  'bihar.prime',
#  'minister',
#  'narendra',
#  'modi',
#  'bjp',
#  'pounced',
#  'accusing',
#  'mr',
#  'channi',
#  'insulting',
#  'states',
#  'icons',
#  '``',
#  'chief',
#  'minister',
#  'insulting',
#  'sant',
#  'ravi',
#  'dass',
#  'dalit',
#  'icon',
#  'born',
#  'benaras',
#  'uttar',
#  'pradesh',
#  'state',
#  'guru',
#  'gobind',
#  'singh',
#  'last',
#  '10',
#  'sikh',
#  'gurus',
#  'born',
#  'patna',
#  'bihar',
#  "''",
#  'asked',
#  'recent',
#  'rally.mr',
#  'modis',
#  'bjp',
#  'alliance',
#  'two',
#  'regional',
#  'parties',
#  'including',
#  'one',
#  'formed',
#  'mr',
#  'singh',
#  'former',
#  'congress',
#  'chief',
#  'minister',
#  'pm',
#  'modis',
#  'right',
#  'bjp',
#  'alliance',
#  'former',
#  'chief',
#  'minister',
#  'amarinder',
#  'singh',
#  'left',
#  'prime',
#  'minister',
#  'also',
#  'attacked',
#  'mr',
#  'kejriwal',
#  'based',
#  'unverified',
#  'allegation',
#  'made',
#  'one',
#  'aap',
#  'leaders',
#  'former',
#  'colleagues',
#  'accused',
#  'supporting',
#  'sikh',
#  'separatists.mr',
#  'kejriwal',
#  'dismissed',
#  'allegation',
#  'saying',
#  'must',
#  '``',
#  'worlds',
#  'sweetest',
#  'terrorist',
#  'builds',
#  'hospitals',
#  "''",
#  '.the',
#  'bjp',
#  'also',
#  'battling',
#  'farmer',
#  'anger',
#  'three',
#  'controversial',
#  'laws',
#  'repealed',
#  'year',
#  'protests',
#  'alliance',
#  'may',
#  'get',
#  'push',
#  'hindu',
#  'minority',
#  'community',
#  'state',
#  'usually',
#  'sided',
#  'party',
#  'power',
#  'centre.the',
#  'sad',
#  'walked',
#  'alliance',
#  'bjp',
#  'farm',
#  'laws',
#  'trying',
#  'hard',
#  'regain',
#  'lost',
#  'ground',
#  'expected',
#  'see',
#  'revival',
#  'congress',
#  'couldnt',
#  'prove',
#  'allegations',
#  'propelled',
#  'power',
#  '2017',
#  'senior',
#  'sad',
#  'leaders',
#  'colluded',
#  'people',
#  'responsible',
#  'incidents',
#  'sacrilege',
#  '2014',
#  '2015.but',
#  'hope',
#  'dashed',
#  'took',
#  'long',
#  'announce',
#  'strong',
#  'stand',
#  'farm',
#  'laws',
#  'later',
#  'supported',
#  'farmers',
#  'protests',
#  'resigned',
#  'mr',
#  'modis',
#  'cabinet',
#  'cut',
#  'ties',
#  'bjp',
#  'issue',
#  'still',
#  'rankles',
#  'minds',
#  'many',
#  'voters.the',
#  'party',
#  'like',
#  'rivals',
#  'announced',
#  'slew',
#  'freebies',
#  'including',
#  'interest-free',
#  'education',
#  'loans',
#  'students',
#  'go',
#  'abroad',
#  'counts',
#  'aspirations',
#  'among',
#  'young',
#  'people',
#  'migrate',
#  'countries',
#  'due',
#  'lack',
#  'jobs',
#  'punjab',
#  'though',
#  'farmers',
#  'protest',
#  'big',
#  'election',
#  'issue',
#  'candidates',
#  'backed',
#  'sanyukt',
#  'samaj',
#  'morcha',
#  'alliance',
#  '22',
#  'farmer',
#  'unions',
#  'took',
#  'shape',
#  'agitation',
#  'unlikely',
#  'win',
#  'observers',
#  'say.read',
#  'coverage',
#  'elections',
#  'india',
#  'india',
#  'election',
#  'test',
#  'modis',
#  'popularitywhy',
#  'west',
#  'uttar',
#  'pradesh',
#  'could',
#  'hurt',
#  'bjp',
#  '’',
#  'poll',
#  'dreamsare',
#  'women',
#  'thriving',
#  'india',
#  'state',
#  'pm',
#  'modi',
#  'claims',
#  'congress',
#  'party',
#  'feud',
#  'punjab',
#  'really',
#  'storyis',
#  'congress',
#  'party',
#  'feud',
#  'punjab',
#  'really',
#  '7',
#  'februarywhy',
#  'pm',
#  'modi',
#  'rolled',
#  'back',
#  'indias',
#  'vexed',
#  'farm',
#  'laws19',
#  'november',
#  '2021related',
#  'topicsasiaindia']

# %% [markdown]
# Construct dictionary of words and sentences according to freq and score

# %%
from nltk.probability import FreqDist
freq_words = FreqDist(words)
freq_words
# Out:
# FreqDist({'congress': 12, 'party': 12, 'mr': 12, 'bjp': 9, 'chief': 9, 'punjab': 8, 'also': 8, 'singh': 8, 'minister': 8, 'aap': 6, ...})

# %%
from heapq import nlargest

# %%
nlargest( 5 , freq_words , key = freq_words.get)
#these are most occuring words in our text
# Out:
# ['congress', 'party', 'mr', 'bjp', 'chief']

# %%
from collections import defaultdict

# %%
# Ranking store the ranking of sentences
ranking = defaultdict(int)

for i,sent in enumerate(sentences):
    for word in word_tokenize( sent.lower() ):
        if word in freq_words:
            ranking[i] += freq_words[word]

# %%
sum_sentences = nlargest( 5 , ranking , key = ranking.get)

# %%
summary = ''
for i in sorted(sum_sentences):
    summary += sentences[i] + '.   '

# %%
summary
# Out:
# 'Both the regional Shiromani Akali Dal (SAD) - which had to do massive damage control after initially speaking in favour of the controversial farm laws - and opposition Bharatiya Janata Party (BJP) hope voters discontent with the ruling Congress party will see them through..   Arvind Kejriwal, AAP chief and Delhi chief minister, alleges that both the Congress party and the SAD have failed to keep their promises to people despite being in power for decades since the state was formed in the 1960s..   He also sparked a controversy by asking voters not to give chances to "outsiders" from Uttar Pradesh and Bihar - in an apparent attack on Mr Kejriwal and Mr Modi who are not from Punjab..   Mr Modis BJP is in an alliance with two regional parties, including the one formed by Mr Singh, the former Congress chief minister..   , PM Modis (right) BJP is in alliance with former chief minister Amarinder Singh (left)The prime minister has also attacked Mr Kejriwal based on an unverified allegation made by one of the AAP leaders former colleagues, who has accused him of supporting Sikh separatists..   '

# %%
def summerizeText( text , n ):
    sentences = text.split('.')
    new_text = '.  '.join(sentences)
    sentences = new_text.split('?')
    new_text = '?  '.join(sentences)
    sentences = sent_tokenize( new_text )
    words = word_tokenize(text.lower())
    newStopWords = set( stopwords.words('english') + list(punctuation) )
    words = [ word for word in words if word not in newStopWords]
    freq_words = FreqDist(words)
    
    ranking = defaultdict(int)

    for i,sent in enumerate(sentences):
        for word in word_tokenize( sent.lower() ):
            if word in freq_words:
                ranking[i] += freq_words[word]
    sum_sentences = nlargest( n , ranking , key = ranking.get)

    summary = ' '.join( sentences[i]  for i in sorted(sum_sentences) )
    return summary

# %%
summerizeText( text , 3 )
# Out:
# 'Arvind Kejriwal, AAP chief and Delhi chief minister, alleges that both the Congress party and the SAD have failed to keep their promises to people despite being in power for decades since the state was formed in the 1960s. Mr Modis BJP is in an alliance with two regional parties, including the one formed by Mr Singh, the former Congress chief minister. , PM Modis (right) BJP is in alliance with former chief minister Amarinder Singh (left)The prime minister has also attacked Mr Kejriwal based on an unverified allegation made by one of the AAP leaders former colleagues, who has accused him of supporting Sikh separatists.'
